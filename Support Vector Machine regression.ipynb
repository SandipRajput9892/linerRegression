# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# from sklearn.metrics import root_mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("placement.csv")
df=pd.DataFrame(dataset)
df.head(5)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.show()

# %%
x=df[["cgpa"]]
y=df["package"]

# %%
x_train,x_test,y_tarin,y_test=train_test_split(x,y,train_size=0.2)

# %%
from sklearn.svm import SVR
model=SVR(kernel="poly")
model.fit(x_train,y_tarin)
# Out:
# SVR(kernel='poly')

# %%
model.predict([[6.89]])
# Out:
# c:\Users\DELL\OneDrive\Documents\AI ML\Linear regression\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([2.81648326])

# %%
sns.scatterplot(x="cgpa", y="package",data=dataset)
plt.plot(dataset["cgpa"],model.predict(x),color="red")
plt.show()
