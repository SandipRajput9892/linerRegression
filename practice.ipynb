# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset=pd.read_csv("Social_Network_Ads (2).csv")
dataset.head(20)
# Out:
#     Age  EstimatedSalary  Purchased
# 0    19            19000          0
# 1    35            20000          0
# 2    26            43000          0
# 3    27            57000          0
# 4    19            76000          0
# 5    27            58000          0
# 6    27            84000          0
# 7    32           150000          1
# 8    25            33000          0
# 9    35            65000          0
# 10   26            80000          0
# 11   26            52000          0
# 12   20            86000          0
# 13   32            18000          0
# 14   18            82000          0
# 15   29            80000          0
# 16   47            25000          1
# 17   45            26000          1
# 18   46            28000          1
# 19   48            29000          1

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=dataset,hue="Purchased")
plt.show()

# %%
dataset.shape
# Out:
# (400, 3)

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
# y=dataset["Salary"]
# print(x)
# print(y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)*100
# Out:
# 83.75

# %%
model.predict([[32	,150000]])
# Out:
# c:\Users\DELL\OneDrive\Documents\AI ML\Linear regression\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# from sklearn.tree import plot_tree
# plt.Figure(figsize=[50,50])
# plt.savefig("graph.jpg")
# plot_tree(model)
# plt.show()


from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 50))  # Capital 'F' in 'Figure' should be lowercase
plot_tree(model)
plt.savefig("graph.jpg", dpi=300)  # Use high DPI for better clarity
plt.show()

# %%
sns.scatterplot(x="Age",y="EstimatedSalary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sns.scatterplot(x="Age",y="EstimatedSalary")
#       2 plt.show()
#
# File c:\Users\DELL\OneDrive\Documents\AI ML\Linear regression\.venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
